# %%
pip install opencv-python
# Out:
# ...
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import os 
import cv2

DATADIR = "C:\\Users\\OgunfowokanPC\\Pictures"
CATEGORIES = ["TAYO_IMG"]

for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array, cmap="gray")
        plt.show()
        break
    break

# %%
os.getcwd()
# Out:
# 'C:\\Users\\OgunfowokanPC'

# %%
print(img_array)
# Out:
# [[ 21  19  18 ... 102 103 104]
#  [ 22  23  23 ...  98  99 100]
#  [ 20  23  25 ...  95  97  98]
#  ...
#  [167 167 167 ... 145 145 145]
#  [167 167 167 ... 144 144 144]
#  [168 168 168 ... 144 144 144]]

# %%
IMG_SIZE= 400

new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array, cmap = 'gray')
plt.show()

# %%
training_data = []
def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                training_data.append([new_array])
            except Exception as e:
                pass
create_training_data()

# %%
print(len(training_data))
# Out:
# 972

# %%
import random

random.shuffle(training_data)

# %%
import pickle

pickle_out = open("training_data.pickle", "wb")
pickle.dump(training_data, pickle_out)
pickle_out.close()

# %%
pickle_in = open("training_data.pickle", "rb")
data = pickle.load(pickle_in)

# %%
import numpy as np
np.save['training_data', np.array(img)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-4064d32bf296> in <module>
#       1 import numpy as np
# ----> 2 np.save['training_data', np.array(img)]
#
# TypeError: 'function' object is not subscriptable

# %%
from numpy import asarray
from numpy import save
save('training_data.npy', training_data)

# %%
import cv2
image = cv2.imread('C:\\Users\\OgunfowokanPC\\Pictures\\VETSARK-Tayo images')
images_gray = cv2.cvtColor(image, cv2.IMREAD_GRAYSCALE)

cv2.imwrite('C:\\Users\\OgunfowokanPC\\Pictures', images_gray)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-38-3cab95b832fa> in <module>
#       1 import cv2
#       2 image = cv2.imread('C:\\Users\\OgunfowokanPC\\Pictures\\VETSARK-Tayo images')
# ----> 3 images_gray = cv2.cvtColor(image, cv2.IMREAD_GRAYSCALE)
#       4
#       5 cv2.imwrite('C:\\Users\\OgunfowokanPC\\Pictures', images_gray)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-kh7iq4w7\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
train = []
def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                train.append([new_array])
            except Exception as e:
                pass
create_training_data()
cv2.imwrite('C:\\Users\\OgunfowokanPC\\Pictures', train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-e8c06a2d84e8> in <module>
#      11                 pass
#      12 create_training_data()
# ---> 13 cv2.imwrite('C:\\Users\\OgunfowokanPC\\Pictures', train)
#
# TypeError: Expected Ptr<cv::UMat> for argument 'img'

# %%
os.listdir('../')
# Out:
# ['Administrator',
#  'All Users',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'OgunfowokanPC',
#  'Public']

# %%
import os

path = 'C:\\Users\\OgunfowokanPC\\Pictures\\TAYO_IMG'

try:
    os.chdir(path)
    print("current working directory: {0}".format(os.getcwd()))
except FileNotFoundError:
    print("Directory: {0} does not exist".format(path))
# Out:
# current working directory: C:\Users\OgunfowokanPC\Pictures\TAYO_IMG

# %%
os.listdir('../')
# Out:
# ['2ndfowlimages',
#  'Camera Roll',
#  'desktop.ini',
#  'fowl.csv',
#  'fowlimages',
#  'images',
#  'IMG_20201009_174502_766.jpg',
#  'IMG_20201010_004248_927.jpg',
#  'newcattle.csv',
#  'run_results.csv',
#  'run_results3.csv',
#  'Saved Pictures',
#  'TAYO_IMG',
#  'VETSARK-Tayo images.rar',
#  'Watch Hunter x Hunter (2011) Episode 26 Online- AnimeDreaming.mp4']

# %%
for IMAGES in os.listdir('../'):
    if state != 'renamed':
        n=0
        for image in os.listdir(f'../{IMAGE}/'):
            data = plt.imread(f'../{IMAGE}/{image}')
            plt.imshow(data)
        cv2.imwrite(f'{state}_{n})

# %%
import glob
from PIL import Image

#Retriving all image names and it's path with .jpg extension from given directory path in imageNames list
imageNames = glob.glob(r"C:\Users\OgunfowokanPC\Pictures\5\*.jpg")

#Defining width and height of image
new_width  = 400-
new_height = 400

#Count variable to show the progress of image resized
count=4324

#Creating for loop to take one image from imageNames list and resize
for i in imageNames:
	img = Image.open(i)
	#img = img.convert('L')
	img = img.transpose(Image.FLIP_LEFT_RIGHT)

    

	#img = img.resize((new_width, new_height), Image.ANTIALIAS)
	#save() to save image at given path and count is the name of image eg. first image name will be 0.jpg
	img.save(r"C:\Users\OgunfowokanPC\Pictures\6\\"+str(count)+".jpg") 
	#incrementing count value
	count+=1
	#showing image resize progress
	print("Images Resized " +str(count)+"/"+str(len(imageNames)),end='\r')
# Out:
# Images Resized 5328/1004

# %%
#Retriving all image names and it's path with .jpg extension from given directory path in imageNames list
imageNames = glob.glob(r"C:\Users\OgunfowokanPC\Pictures\TAYO_IMG\*.jpg")

#Defining width and height of image
new_width  = 400
new_height = 400

#Count variable to show the progress of image resized
count=760

#Creating for loop to take one image from imageNames list and resize
for i in imageNames:
	#opening image for editing
	img = Image.open(i)
	img = img.convert('L')
	#img = img.resize((new_width, new_height), Image.ANTIALIAS)
	#save() to save image at given path and count is the name of image eg. first image name will be 0.jpg
	img.save(r"C:\Users\OgunfowokanPC\Pictures\TAYO_IMG\preprocessed\\"+str(count)+".jpg") 
	#incrementing count value
	count+=1
	#showing image resize progress
	print("Images Resized " +str(count)+"/"+str(len(imageNames)),end='\r')
# Out:
# Images Resized 974/214

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
import os
i = 0
path = os.chdir(r'C:\Users\OgunfowokanPC\Pictures\unhealthy')

for file in os.listdir(path):
    new_file_name = "healthy.{}.jpg".format(i)
    os.rename(file, new_file_name)
    i = i+1

# %%
import os
i = 0
path = os.chdir(r'C:\Users\OgunfowokanPC\Pictures\unhealthy')

for file in os.listdir(path):
    new_file_name = "unhealthy.{}.jpg".format(i)
    os.rename(file, new_file_name)
    i = i+1
